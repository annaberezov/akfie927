# %% [markdown]
# <a href="https://colab.research.google.com/github/annaberezov/akfie927/blob/main/Berezovski_Project6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Six
# ##Anna-Maria Berezovski
# ##CSC 687
# ##March 7, 2022

# %% [markdown]
# ## Data Imports and Prep

# %%
# Pandas is mainly used for data analysis. Pandas allows importing data from various file formats 
# such as comma-separated values, JSON, SQL, Microsoft Excel. 
# Pandas allows various data manipulation operations such as merging, reshaping, selecting, 
# as well as data cleaning, and data wrangling features.
import pandas as pd

# Import matplotlib and seaborn libraries to visualize the data
import matplotlib.pyplot as plt 
import seaborn as sns

# Read raw filefrom github into a dataframe
# Company_data: Amounts spent on different types of advertisements and the resulting Sales
df = pd.read_csv('fetal_health.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
df
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
df.corr()
# Out:
#                                                     baseline value  \
# baseline value                                            1.000000
# accelerations                                            -0.080560
# fetal_movement                                           -0.033436
# uterine_contractions                                     -0.146373
# light_decelerations                                      -0.159032
# severe_decelerations                                     -0.053518
# prolongued_decelerations                                 -0.104597
# abnormal_short_term_variability                           0.305570
# mean_value_of_short_term_variability                     -0.279607
# percentage_of_time_with_abnormal_long_term_vari...        0.285630
# mean_value_of_long_term_variability                      -0.032091
# histogram_width                                          -0.147679
# histogram_min                                             0.361619
# ...

# %%
corr_matrix = df.corr()

corr_matrix["fetal_health"].sort_values(ascending=False)

sns.heatmap(corr_matrix)

# %%
pd.crosstab(df['accelerations'], df['fetal_health']).plot.bar(stacked=False, figsize=(15,10))

# %%
pd.crosstab(df['uterine_contractions'], df['fetal_health']).plot.bar(stacked=False, figsize=(15,10))

# %%
pd.crosstab(df['prolongued_decelerations'], df['fetal_health']).plot.bar(stacked=False, figsize=(15,10))

# %%
pd.crosstab(df['abnormal_short_term_variability'], df['fetal_health']).plot.bar(stacked=False, figsize=(15,10))

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f81ada51090>,
# ...
#       dtype=object)

# %%
# let's plot the 8 attributes

import matplotlib.pyplot as plt

f, axes = plt.subplots(11,2, figsize=(20,40))

sns.distplot(df['baseline value'], ax=axes[0,0])
sns.distplot(df.accelerations, ax=axes[0,1])

sns.distplot(df.fetal_movement, ax=axes[1,0])
sns.distplot(df.uterine_contractions, ax=axes[1,1])

sns.distplot(df.light_decelerations, ax=axes[2,0])
sns.distplot(df.severe_decelerations, ax=axes[2,1])

sns.distplot(df.prolongued_decelerations, ax=axes[3,0])
sns.distplot(df.abnormal_short_term_variability, ax=axes[3,1])

sns.distplot(df.mean_value_of_short_term_variability, ax=axes[4,0])
sns.distplot(df.percentage_of_time_with_abnormal_long_term_variability, ax=axes[4,1])

sns.distplot(df.mean_value_of_long_term_variability, ax=axes[5,0])
sns.distplot(df.histogram_width, ax=axes[5,1])

sns.distplot(df.histogram_min, ax=axes[6,0])
sns.distplot(df.histogram_max, ax=axes[6,1])

sns.distplot(df.histogram_number_of_peaks, ax=axes[7,0])
sns.distplot(df.histogram_number_of_zeroes, ax=axes[7,1])

sns.distplot(df.histogram_mode, ax=axes[8,0])
sns.distplot(df.histogram_mean, ax=axes[8,1])

sns.distplot(df.histogram_median, ax=axes[9,0])
sns.distplot(df.histogram_variance, ax=axes[9,1])

sns.distplot(df.histogram_tendency, ax=axes[10,0])
sns.distplot(df.fetal_health, ax=axes[10,1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Class distributions

# %%
sns.countplot(x="fetal_health", data=df)

# %% [markdown]
# Clean data -> standard scaling does nothing
# no missing values
# no encoding needed since target is already a number

# %%
# let's replace the filler 0 values with the median 

df.abnormal_short_term_variability.replace(0., df.abnormal_short_term_variability.median(), inplace=True)
df.prolongued_decelerations.replace(0., df.prolongued_decelerations.median(), inplace=True)
df.uterine_contractions.replace(0., df.uterine_contractions.median(), inplace=True)
df.accelerations.replace(0., df.accelerations.median(), inplace=True)
df['baseline value'].replace(0., df['baseline value'].median(), inplace=True)
df.fetal_movement.replace(0., df.fetal_movement.median(), inplace=True)
df.light_decelerations.replace(0., df.light_decelerations.median(), inplace=True)
df.severe_decelerations.replace(0., df.severe_decelerations.median(), inplace=True)
df.prolongued_decelerations.replace(0., df.prolongued_decelerations.median(), inplace=True)
df.mean_value_of_short_term_variability.replace(0., df.mean_value_of_short_term_variability.median(), inplace=True)
df.percentage_of_time_with_abnormal_long_term_variability.replace(0., df.percentage_of_time_with_abnormal_long_term_variability.median(), inplace=True)
df.mean_value_of_long_term_variability.replace(0., df.mean_value_of_long_term_variability.median(), inplace=True)
df.histogram_width.replace(0., df.histogram_width.median(), inplace=True)
df.histogram_min.replace(0., df.histogram_min.median(), inplace=True)
df.histogram_max.replace(0., df.histogram_max.median(), inplace=True)
df.histogram_number_of_peaks.replace(0., df.histogram_number_of_peaks.median(), inplace=True)
df.histogram_number_of_zeroes.replace(0., df.histogram_number_of_zeroes.median(), inplace=True)
df.histogram_mode.replace(0., df.histogram_mode.median(), inplace=True)
df.histogram_mean.replace(0., df.histogram_mean.median(), inplace=True)
df.histogram_median.replace(0., df.histogram_median.median(), inplace=True)
df.histogram_variance.replace(0., df.histogram_variance.median(), inplace=True)
df.histogram_tendency.replace(0., df.histogram_tendency.median(), inplace=True)

# %%
# select which variables we will use to train our model with

# X = df[['abnormal_short_term_variability', 'prolongued_decelerations', 'uterine_contractions', 'accelerations']]
# y = df['fetal_health']

# %%
# all numeric values needs to be scaled

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# remove the dependent (predictor) parameter from the training set
X = df.drop('fetal_health', axis =1)
y = df.fetal_health

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# set aside the normalized data for training and testing
X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.2, random_state=22)

# %%
y_test.reset_index(drop=True)
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 421    1.0
# 422    1.0
# 423    1.0
# 424    1.0
# 425    2.0
# Name: fetal_health, Length: 426, dtype: float64

# %% [markdown]
# ## Training the Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Dense, Dropout, Flatten

# train a network with one hidden layer (50 nodes) and one output node
# too many hidden layers and nodes/hidden layer can cause overfitting
# experiment with these parameters to better observe the model behavior
model = keras.models.Sequential([
        keras.layers.Flatten(input_shape=[X_train.shape[1],]),
  
        keras.layers.Dense(50, activation="relu"),

        keras.layers.Dense(1, activation="sigmoid")
])

# %%
# lets examine the model architecture

model.summary()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_30 (Flatten)        (None, 21)                0
#
#  dense_74 (Dense)            (None, 50)                1100
#
#  dense_75 (Dense)            (None, 1)                 51
#
# ...
# Total params: 1,151
# Trainable params: 1,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model using appropriate parameters
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])


# fit() produces a history object that contains all the details about the classifier including accuracy scores
# experiment with epochs and batch_size to see how they affect overall accuracy
history = model.fit(x=X_train, y=y_train, epochs=150, batch_size=128, validation_data=(X_test, y_test), verbose=0)

# we can track accuracy/loss as well as validated accuracy/loss measures
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Let's get a prediction and a classification report from the model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


#y_pred = model.predict_classes(X_test)  deprecated
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# print various classification performance measures
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
# [[337   0   0]
#  [ 56   0   0]
#  [ 33   0   0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.79      1.00      0.88       337
#
#    micro avg       0.79      1.00      0.88       337
#    macro avg       0.40      0.50      0.44       337
# weighted avg       0.79      1.00      0.88       337
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# the close gaps between accuracy/loss and validated accuracy/loss verify that
# overfitting is not severe in the model

from sklearn.metrics import classification_report, accuracy_score
from matplotlib import pyplot
from numpy import where

# plot model accuracy and loss during training
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()

# %%
# cross validation in keras is somewhat different than in sklearn

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np

# create the sequential NN model
def create_baseline():
    model = keras.models.Sequential([keras.layers.Flatten(), 
                                     keras.layers.Dense(50, activation="relu"), 
                                     keras.layers.Dense(1, activation="sigmoid") ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model


# evaluate model with standardized dataset
estimator = KerasClassifier(build_fn=create_baseline, epochs=150, verbose=0)

# do a 3-fold CV on the entire dataset
kfold = StratifiedKFold(n_splits=3, shuffle=True)
results = cross_val_score(estimator, scaled_X, y, cv=kfold)

print("Baseline accuracy: %.2f%% (+/- %.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# Baseline accuracy: 75.68% (+/- 1.14%)

# %% [markdown]
# Training a different model with different layers

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Dense, Dropout, Flatten

# train a network with two hidden layers (50 nodes) and one output node
# too many hidden layers and nodes/hidden layer can cause overfitting
# experiment with these parameters to better observe the model behavior
model = keras.models.Sequential([
        keras.layers.Flatten(input_shape=[X_train.shape[1],]),
  
        keras.layers.Dense(50, activation="relu"),

        keras.layers.Dense(50, activation="relu"),

        keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.summary()
# Out:
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_34 (Flatten)        (None, 21)                0
#
#  dense_82 (Dense)            (None, 50)                1100
#
#  dense_83 (Dense)            (None, 50)                2550
#
#  dense_84 (Dense)            (None, 1)                 51
#
# ...
# Total params: 3,701
# Trainable params: 3,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model using appropriate parameters
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])


# fit() produces a history object that contains all the details about the classifier including accuracy scores
# experiment with epochs and batch_size to see how they affect overall accuracy
history = model.fit(x=X_train, y=y_train, epochs=150, batch_size=128, validation_data=(X_test, y_test), verbose=0)

# we can track accuracy/loss as well as validated accuracy/loss measures
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Let's get a prediction and a classification report from the model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


#y_pred = model.predict_classes(X_test)  deprecated
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# print various classification performance measures
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
# [[337   0   0]
#  [ 56   0   0]
#  [ 33   0   0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.79      1.00      0.88       337
#
#    micro avg       0.79      1.00      0.88       337
#    macro avg       0.40      0.50      0.44       337
# weighted avg       0.79      1.00      0.88       337
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# the close gaps between accuracy/loss and validated accuracy/loss verify that
# overfitting is not severe in the model

from sklearn.metrics import classification_report, accuracy_score
from matplotlib import pyplot
from numpy import where

# plot model accuracy and loss during training
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()

# %%
# cross validation in keras is somewhat different than in sklearn

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np

# create the sequential NN model
def create_baseline():
    model = keras.models.Sequential([keras.layers.Flatten(), 
                                     keras.layers.Dense(50, activation="relu"),
                                     keras.layers.Dense(50, activation="relu"),  
                                     keras.layers.Dense(1, activation="sigmoid") ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model


# evaluate model with standardized dataset
estimator = KerasClassifier(build_fn=create_baseline, epochs=150, verbose=0)

# do a 3-fold CV on the entire dataset
kfold = StratifiedKFold(n_splits=3, shuffle=True)
results = cross_val_score(estimator, scaled_X, y, cv=kfold)

print("Baseline accuracy: %.2f%% (+/- %.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# Baseline accuracy: 76.15% (+/- 0.88%)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Dense, Dropout, Flatten

# train a network with two hidden layers (50 nodes) and one output node
# too many hidden layers and nodes/hidden layer can cause overfitting
# experiment with these parameters to better observe the model behavior
model = keras.models.Sequential([
        keras.layers.Flatten(input_shape=[X_train.shape[1],]),
  
        keras.layers.Dense(25, activation="relu"),

        keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_38 (Flatten)        (None, 21)                0
#
#  dense_94 (Dense)            (None, 25)                550
#
#  dense_95 (Dense)            (None, 1)                 26
#
# ...
# Total params: 576
# Trainable params: 576
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model using appropriate parameters
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])


# fit() produces a history object that contains all the details about the classifier including accuracy scores
# experiment with epochs and batch_size to see how they affect overall accuracy
history = model.fit(x=X_train, y=y_train, epochs=150, batch_size=128, validation_data=(X_test, y_test), verbose=0)

# we can track accuracy/loss as well as validated accuracy/loss measures
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Let's get a prediction and a classification report from the model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


#y_pred = model.predict_classes(X_test)  deprecated
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# print various classification performance measures
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
# [[337   0   0]
#  [ 56   0   0]
#  [ 33   0   0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.79      1.00      0.88       337
#
#    micro avg       0.79      1.00      0.88       337
#    macro avg       0.40      0.50      0.44       337
# weighted avg       0.79      1.00      0.88       337
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# the close gaps between accuracy/loss and validated accuracy/loss verify that
# overfitting is not severe in the model

from sklearn.metrics import classification_report, accuracy_score
from matplotlib import pyplot
from numpy import where

# plot model accuracy and loss during training
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()

# %%
# cross validation in keras is somewhat different than in sklearn

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np

# create the sequential NN model
def create_baseline():
    model = keras.models.Sequential([keras.layers.Flatten(), 
                                     keras.layers.Dense(25, activation="relu"),  
                                     keras.layers.Dense(1, activation="sigmoid") ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model


# evaluate model with standardized dataset
estimator = KerasClassifier(build_fn=create_baseline, epochs=150, verbose=0)

# do a 3-fold CV on the entire dataset
kfold = StratifiedKFold(n_splits=3, shuffle=True)
results = cross_val_score(estimator, scaled_X, y, cv=kfold)

print("Baseline accuracy: %.2f%% (+/- %.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# Baseline accuracy: 75.92% (+/- 0.88%)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In the first model, it used one layer with 50 folds. The resulting accuracy was reported to be 75.68%. The second model used two layers each with 50 folds. This model's accuracy was 76.15%. The final model used one layer with 25 folds and had an accuracy of 75.92%. With these results, we can see that the difference between using 50 folds or 25 folds for one layered models has an insignificant difference in this case. But, in using the two layers with 50 folds each, we were able to get the most accuracy. This shows that there is some improvement, but it is not very significant. This indicates to me that this might be the rough overall accuracy this type of model can obtain with this data.
#
# Finally, I was concerned with the UndefinedMetricWarning and the resulting 0's in the confusion matrix. To try and solve this issue I worked with the data, cleaning out the 0s in the data as well as using different variables to train the model with. I also made sure that the data used as the X and y values were correct in that the target value was not included in the X and only the target value is in the y as this was the solution the last time I had the same warning.
